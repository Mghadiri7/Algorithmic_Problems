# %%
from random import randint as rnd
import matplotlib.pyplot as plt

# %%
N = 100
length = 20
_list = [rnd(1, N) for i in range(length)]
print(_list)

# %%
for i in range(length-1):
    _min = i
    for j in range(i+1 , length):
        if _list[j]<_list[_min]:
            _min = j
    _list[i], _list[_min] = _list[_min], _list[i]
    plt.bar(list(range(length)), _list)
    plt.pause(0.005)
    plt.clf()
plt.show()
print(_list)
# Out:
# [53, 49, 14, 92, 63, 97, 71, 53, 14, 62, 7, 77, 74, 79, 27, 65, 90, 57, 50, 75]
# [7, 14, 14, 27, 49, 50, 53, 53, 57, 62, 63, 65, 71, 74, 75, 77, 79, 90, 92, 97]
